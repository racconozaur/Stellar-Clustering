# %%
import pandas as pd
import networkx as nx
import pickle

# %%
pd_line = pd.read_csv('LINE_res/tx_line_hdbscan_cosine_pca64.csv')

# %%
print(pd_line.head(1))
# Out:
#    node_id     dim_0    dim_1     dim_2    dim_3     dim_4     dim_5    dim_6  \
# 0        1  0.822308  1.45785 -1.617054  1.31011  0.976359 -0.931209 -0.98724
#
#       dim_7     dim_8  ...   dim_121   dim_122   dim_123   dim_124   dim_125  \
# 0 -0.487009  1.020912  ... -0.613616 -0.420441  0.227259  0.736358  0.259724
#
#     dim_126   dim_127  hdbscan_mcs20  hdbscan_mcs50  hdbscan_mcs100
# 0  0.772156  0.095179              1             -1              -1
#
# [1 rows x 132 columns]

# %%
pd_node2vec = pd.read_csv('Node2Vec_res/tx_node2vec_hdbscan_cosine_pca64.csv')

# %%
print(pd_node2vec.head(1))
# Out:
#    account_id        z1        z2        z3        z4        z5       z6  \
# 0         130  0.124424  0.276466 -0.064029 -0.005956 -0.319771  0.01542
#
#          z7        z8        z9  ...      z122      z123      z124      z125  \
# 0  0.051697  0.122329 -0.291541  ...  0.099538 -0.012433 -0.113928  0.033742
#
#        z126      z127      z128  hdbscan_mcs20  hdbscan_mcs50  hdbscan_mcs100
# 0  0.085884 -0.175961  0.034045            399             -1              -1
#
# [1 rows x 132 columns]

# %%
import pandas as pd
import networkx as nx
import pickle

# %%
pd_line = pd.read_csv('LINE_res/transactions_line_kmeans_results.csv')

# %%
print(pd_line.head(1))
# Out:
#    node_id     dim_0    dim_1     dim_2    dim_3     dim_4     dim_5    dim_6  \
# 0        1  0.822308  1.45785 -1.617054  1.31011  0.976359 -0.931209 -0.98724
#
#       dim_7     dim_8  ...  kmeans_80  kmeans_100  kmeans_120  kmeans_150  \
# 0 -0.487009  1.020912  ...         35          93          32          61
#
#    kmeans_180  kmeans_210  kmeans_250  kmeans_300  kmeans_350  kmeans_400
# 0         132          85         156         117         317         195
#
# [1 rows x 148 columns]

# %%
pd_node2vec = pd.read_csv('Node2Vec_res/transactions_node2vec_kmeans_results.csv')

# %%
print(pd_node2vec.head(1))
# Out:
#    account_id        z1        z2        z3        z4        z5       z6  \
# 0         130  0.124424  0.276466 -0.064029 -0.005956 -0.319771  0.01542
#
#          z7        z8        z9  ...  kmeans_80  kmeans_100  kmeans_120  \
# 0  0.051697  0.122329 -0.291541  ...         18           2          39
#
#    kmeans_150  kmeans_180  kmeans_210  kmeans_250  kmeans_300  kmeans_350  \
# 0         144         166         166         166         219         104
#
#    kmeans_400
# 0         212
#
# [1 rows x 148 columns]

# %%
import pandas as pd

# %%
emb_path = "stellar_line_embeddings_order2.csv"
emb = pd.read_csv(emb_path)

# %%
print(emb.shape)
print(emb.head())
# Out:
# (4315652, 129)
#    node_id     dim_0     dim_1     dim_2     dim_3     dim_4     dim_5  \
# 0        1  0.822308  1.457850 -1.617054  1.310110  0.976359 -0.931209
# 1      130  0.686141 -0.402493  0.771425 -0.351421  1.282274 -0.868468
# 2      432 -0.002269 -0.010151  0.030211  0.020537 -0.033369 -0.040869
# 3      491  0.011651 -0.005007  0.018671  0.047320 -0.016311 -0.063477
# 4      700 -0.016078 -0.019927  0.022537  0.013101  0.002769 -0.061232
#
#       dim_6     dim_7     dim_8  ...   dim_118   dim_119   dim_120   dim_121  \
# 0 -0.987240 -0.487009  1.020912  ... -0.964779  1.536676 -0.561855 -0.613616
# 1  0.795994 -0.105109  0.440420  ... -0.228627 -0.215782 -1.246331  1.444834
# 2 -0.018746  0.014174  0.017210  ...  0.041306  0.026113 -0.052341  0.021097
# 3 -0.042498  0.029040  0.007093  ...  0.039358  0.002017 -0.001849  0.022040
# 4 -0.044671  0.007303  0.025715  ... -0.006624  0.036177 -0.032274  0.029641
#
# ...

# %%
emb.rename(columns={'node_id': 'account_id'}, inplace=True)

emb.to_csv('your_file.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 emb.rename(columns={'node_id': 'account_id'}, inplace=True)
# ----> 4 emb.to_csv('your_file.csv', index=False)
#
# File ~/stellar-clustering/.venv-vis/lib/python3.9/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

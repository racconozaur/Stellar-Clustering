# %%
import pandas as pd

# %%
emb_path = "txlcc_node2vec_d128_p1_q2_wl30_nw10_w10_pecanpy.csv"
emb = pd.read_csv(emb_path)

# %%
print(emb.shape)
print(emb.head())
# Out:
# (4315652, 129)
#    account_id        z1        z2        z3        z4        z5        z6  \
# 0         130  0.124424  0.276466 -0.064029 -0.005956 -0.319771  0.015420
# 1      201093 -0.109684  0.589938  0.060745 -0.204437 -0.598159  0.407886
# 2         149 -0.005842 -0.120701 -0.383479  0.058483 -0.031817  0.219283
# 3        4946 -0.341861  0.209907 -0.189889  0.308259 -0.216381  0.135159
# 4    34307391 -0.030285  0.358729  0.141146  0.083795  0.272350 -0.030318
#
#          z7        z8        z9  ...      z119      z120      z121      z122  \
# 0  0.051697  0.122329 -0.291541  ...  0.205447 -0.453355  0.020590  0.099538
# 1 -0.018822 -0.078111 -0.245053  ...  0.048334 -0.314339  0.165239 -0.265408
# 2 -0.234502  0.067060  0.039888  ... -0.073084 -0.657581  0.334375  0.272149
# 3  0.422111  0.176049 -0.034252  ...  0.448778  0.077607  0.099752 -0.289850
# 4  0.211803  0.087312 -0.159290  ...  0.418487 -0.240432 -0.032716 -0.180296
#
# ...

# %%
import pandas as pd
import networkx as nx
import pickle

# %%
data = pd.read_csv('transaction_edges_minimal.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/parsers.pyx:1067, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File pandas/_libs/parsers.pyx:1177, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File pandas/_libs/parsers.pyx:1837, in pandas._libs.parsers._try_int64()
#
# ValueError: Number is not int
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = pd.read_csv('transaction_edges_minimal.csv')
#
# ...

# %%
metadata = pd.read_csv('transaction_edges_metadata.csv')

# %%
print(data.head(1))
# Out:
#          operation_id  sender_id  receiver_id     tx_date   amount
# 0  235592927714390017     102965     25668647  2025-01-01  2.54332

# %%
print(metadata.head(1))
# Out:
#          operation_id  sender_id  receiver_id  \
# 0  235592927714390017     102965     25668647
#
#                                       sender_address  \
# 0  GADYBYSRCRNGCL3KUZDMN2KXHLATBGQ3Z3GFL26C57HEDL...
#
#                                     receiver_address  \
# 0  GCP7YFYVZ2F6SWODILO42WKBE5KY2W67XC7E7ZSUDAXT5P...
#
#                  tx_timestamp         asset_type asset_code  \
# 0  2025-01-01 11:58:16.794914  credit_alphanum12      WAAVE
#
#                                         asset_issuer
# 0  GD4NBR7U3FWKS7M7C7A3XUWIMNJPGTZ5WZDS3QSQTCXTSU...

# %% [markdown]
# ---- Full

# %%
with open("pkl/tx_undirected_weighted_graph.pkl","rb") as f:
    G_full = pickle.load(f)

# %%
print(f"Number of full nodes: {G_full.number_of_nodes()}")
print(f"Number of full edges: {G_full.number_of_edges()}")
# Out:
# Number of full nodes: 4318356
# Number of full edges: 7223800

# %%
print(list(G_full.nodes())[:10]) # node ID == account id
# Out:
# [1, 130, 432, 491, 700, 708, 831, 1022, 1326, 4584]

# %% [markdown]
# ------ LCC

# %%
with open("LCC/LCC_G_tx_undirected_weighted.pkl","rb") as f:
    G_lcc = pickle.load(f)

# %%
print(f"Number of full nodes: {G_lcc.number_of_nodes()}")
print(f"Number of full edges: {G_lcc.number_of_edges()}")
# Out:
# Number of full nodes: 4315652
# Number of full edges: 7100549

# %%
print(list(G_lcc.nodes())[:10])
# Out:
# [1, 130, 432, 491, 700, 708, 831, 1022, 1326, 4584]

# %%
print(list(G_lcc.edges())[:10])
# Out:
# [(1, 130), (1, 432), (1, 491), (1, 700), (1, 708), (1, 831), (1, 1022), (1, 1326), (1, 4584), (1, 4742)]

# %%
print(" Edge Attributes:", G_lcc.edges[1, 700])
# Out:
#  Edge Attributes: {'weight': 5, 'tx_count': 5, 'amount_sum': 2.0}

# %%
isolates = list(nx.isolates(G_lcc))
print("isolates: ", {len(isolates)})
# Out:
# isolates:  {0}

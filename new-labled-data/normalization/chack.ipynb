# %%
import pickle, os

GRAPH_PKL = os.path.expanduser("~/stellar-clustering/publication/data/LCC/LCC_G_tx_undirected_weighted.pkl")

with open(GRAPH_PKL, "rb") as f:
    G = pickle.load(f)

print(f"Type:  {type(G).__name__}")
print(f"Nodes: {G.number_of_nodes():,}")
print(f"Edges: {G.number_of_edges():,}")

# first 5 nodes
print("\nSample nodes:")
for n in list(G.nodes())[:5]:
    print(f"  {repr(n)}")

# first 5 edges with attributes
print("\nSample edges:")
for u, v, data in list(G.edges(data=True))[:5]:
    print(f"  {u} -- {v}  {data}")

# graph-level attributes
print(f"\nGraph attrs: {dict(G.graph)}")
# Out:
# Type:  Graph
# Nodes: 4,315,652
# Edges: 7,100,549
#
# Sample nodes:
#   1
#   130
#   432
#   491
#   700
#
# Sample edges:
#   1 -- 130  {'weight': 3, 'tx_count': 3, 'amount_sum': 3e-06}
#   1 -- 432  {'weight': 4, 'tx_count': 4, 'amount_sum': 1.6}
#   1 -- 491  {'weight': 4, 'tx_count': 4, 'amount_sum': 1.6}
#   1 -- 700  {'weight': 5, 'tx_count': 5, 'amount_sum': 2.0}
#   1 -- 708  {'weight': 4, 'tx_count': 4, 'amount_sum': 1.6}
#
# Graph attrs: {}

# %%
import pickle, os
with open(os.path.expanduser("~/stellar-clustering/publication/data/LCC/LCC_G_tx_undirected_weighted.pkl"), "rb") as f:
    G = pickle.load(f)
n = next(iter(G.nodes()))
print(repr(n), type(n).__name__)
# Out:
# 1 int
